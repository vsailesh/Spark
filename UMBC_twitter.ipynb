# %%
import tweepy
from IPython.display import display

# %%
#pip install Ipython
# pip install tweepy

# %%
API_Key="mHKTYlXVmT73Ov1md4JanBNZ7"
API_Key_Secret="7XqdDMrZcBPsxe3z09sDRsPZuhrz65loAeAbPckeukIfehZcIO"
Bearer_token="AAAAAAAAAAAAAAAAAAAAAETAdQEAAAAAFMELfZTkLUgVQOMqC3i%2BN%2Bcc8ek%3D8h7KebgiaWr3bWyAXAbRL0mqmA2urP4gnLclGsCSdSTvSjZWPQ"
Access_token="1533981877207441410-6nP1kDslR8NI87y3QaDZaUoqx0gfkL"
Access_token_sec="IEUOilOKE3elCTAvZ7BfmDRvfa1UqaqVRzDvOZiatI4Lm"

# %%
def twitter_umbc_setup():
    
    auth=tweepy.OAuthHandler(API_Key,API_Key_Secret )
    auth.set_access_token(Access_token,Access_token_sec)
    
    api= tweepy.API(auth)
    return api

# %%
extractor= twitter_umbc_setup()
Hash_Tag= input("Please enter Hash Tag : ")
tweets= extractor.search_tweets(q=Hash_Tag, count=1000)
print("Total Number of tweets Extracted : {}.\n ". format(len(tweets)))
# Out:
# Please enter Hash Tag : #ntrgoesglobal
# Total Number of tweets Extracted : 100.

# %%
for tweet in tweets:
    print(tweet.text,"\n")
# Out:
# RT @fanofTaraka9999: #ManOfMassesNTR Annaya 🖤🖤... #NTR30 #NTRGoesGlobal
# @tarak9999 https://t.co/vPWr548Cty
#
# RT @Agentbramhi: Bahubali ❌ Rrr
# @tarak9999
# #ManOfMassesNTR #NTRGoesGlobal
# #NTR30 https://t.co/PhPumMEKTn
#
# RT @ChowDary2413: @tarak9999 Along with #LakshmiPranathi 🤩❤️ #ManOfMassesNTR #NTRGoesGlobal #NTR30 #NTRforBimbisara https://t.co/wvaLMaMv70
#
# RT @fanofTaraka9999: #ManOfMassesNTR Annaya 🖤🖤... #NTR30 #NTRGoesGlobal
# @tarak9999 https://t.co/vPWr548Cty
#
# RT @Agentbramhi: Bahubali ❌ Rrr
# @tarak9999
# #ManOfMassesNTR #NTRGoesGlobal
# #NTR30 https://t.co/PhPumMEKTn
#
# RT @ChowDary2413: Latest Snap @tarak9999 #ManOfMassesNTR #NTRGoesGlobal #NTR30 https://t.co/xK4aCWYAz1
#
# RT @Tarak____9999: Songs Trending lo undatam chusanu Movies Trending lo undatam chusanu Akariki Interviews kuda Trending lo Undatam chusanu…
#
# RT @Agentbramhi: Bahubali ❌ Rrr
# @tarak9999
# #ManOfMassesNTR #NTRGoesGlobal
# #NTR30 https://t.co/PhPumMEKTn
#
# ...

# %%
## Source: https://towardsdatascience.com/step-by-step-twitter-sentiment-analysis-in-python-d6f650ade58d
